# %% [markdown]
# <a href="https://colab.research.google.com/github/youngmin5068/ComputerVision/blob/main/UNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torchsummary
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.7/dist-packages (1.5.1)

# %%
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import DataLoader,Dataset
from torch.utils.tensorboard import SummaryWriter
from torchvision import transforms,datasets
import torchvision

# %%
class UNet(torch.nn.Module):
    def __init__(self):
        super().__init__()

		# Convolution, Batch Normalization, ReLU 연산을 합친 함수
        def CBR2d(input_channel, output_channel, kernel_size=3, stride=1,padding=0):
            layer = nn.Sequential(
                nn.Conv2d(input_channel, output_channel, kernel_size=kernel_size, stride=stride,padding=padding),
                nn.BatchNorm2d(num_features=output_channel),
                nn.ReLU()
            )
            return layer

		# Contracting path
        # 572x572x1 => 568x568x64
        self.conv1 = nn.Sequential(
            CBR2d(1, 64, 3, 1),
            CBR2d(64, 64, 3, 1)
        )
		# 568x568x64 => 284x284x64 		
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)


		# 284x284x64 => 280x280x128
        self.conv2 = nn.Sequential(
            CBR2d(64, 128, 3, 1),
            CBR2d(128, 128, 3, 1)
        )
		# 280x280x128 => 140x140x128
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)


		# 140x140x128 => 136x136x256
        self.conv3 = nn.Sequential(
            CBR2d(128, 256, 3, 1),
            CBR2d(256, 256, 3, 1)
        )
		# 136x136x256 => 68x68x256
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)


		# 68x68x256 => 64x64x512
        # Contracting path 마지막에 Dropout 적용
        self.conv4 = nn.Sequential(
            CBR2d(256, 512, 3, 1),
            CBR2d(512, 512, 3, 1),
            nn.Dropout(p=0.5)
        )
		# 64x64x512 => 32x32x512
        self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2)
		# Contracting path 끝
        
		
        # Bottlneck 구간
        # 32x32x512 => 28x28x1024
        self.bottleNeck = nn.Sequential(
            CBR2d(512, 1024, 3, 1),
            CBR2d(1024, 1024, 3, 1),
        )
		# Bottlneck 구간 끝


		# Expanding path
        # channel 수를 감소 시키며 Up-Convolution
		# 28x28x1024 => 56x56x512        
        self.upconv1 = nn.ConvTranspose2d(in_channels=1024, out_channels=512, kernel_size=2, stride=2)


		# Up-Convolution 이후 channel = 512
        # Contracting path 중 같은 단계의 Feature map을 가져와 Up-Convolution 결과의 Feature map과 Concat 연산
        # => channel = 1024 가 됩니다.
        # forward 부분을 참고해주세요
        # 56x56x1024 => 52x52x512
        self.ex_conv1 = nn.Sequential(
            CBR2d(1024, 512, 3, 1),
            CBR2d(512, 512, 3, 1)
        )

		# 52x52x512 => 104x104x256
        self.upconv2 = nn.ConvTranspose2d(in_channels=512, out_channels=256, kernel_size=2, stride=2)

		# 104x104x512 => 100x100x256
        self.ex_conv2 = nn.Sequential(
            CBR2d(512, 256, 3),
            CBR2d(256, 256, 3)
        )

		# 100x100x256 => 200x200x128
        self.upconv3 = nn.ConvTranspose2d(in_channels=256, out_channels=128, kernel_size=2, stride=2)

		# 200x200x256 => 196x196x128
        self.ex_conv3 = nn.Sequential(
            CBR2d(256, 128, 3),
            CBR2d(128, 128, 3)
        )

		# 196x196x128 => 392x392x64
        self.upconv4 = nn.ConvTranspose2d(in_channels=128, out_channels=64, kernel_size=2, stride=2)

		# 392x392x128 => 388x388x64
        self.ex_conv4 = nn.Sequential(
            CBR2d(128, 64, 3),
            CBR2d(64, 64, 3),
            #nn.Conv2d(64, 64, kernel_size=2, stride=1,padding=0)

        )

		# 논문 구조상 output = 2 channel
	    # train 데이터에서 세포 / 배경을 검출하는것이 목표여서 class_num = 1로 지정
		# 388x388x64 => 388x388x1
        self.fc = nn.Conv2d(64, 1, kernel_size=1, stride=1)


    def forward(self, x):
    	# Contracting path
        # 572x572x1 => 568x568x64
        layer1 = self.conv1(x)
        
        # Max Pooling
        # 568x568x64 => 284x284x64
        out = self.pool1(layer1)

		# 284x284x64 => 280x280x128
        layer2 = self.conv2(out)
        
        # Max Pooling
        # 280x280x128 => 140x140x128
        out = self.pool2(layer2)

		# 140x140x128 => 136x136x256
        layer3 = self.conv3(out)
        
        # Max Pooling
        # 136x136x256 => 68x68x256
        out = self.pool3(layer3)

		# 68x68x256 => 64x64x512
        layer4 = self.conv4(out)
        
        # Max Pooling
        # 64x64x512 => 32x32x512
        out = self.pool4(layer4)

		# bottleneck 
        # 32x32x512 => 28x28x1024
        bottleNeck = self.bottleNeck(out)

		# Expanding path
        # 28x28x1024 => 56x56x512
        upconv1 = self.upconv1(bottleNeck)
        
        # Contracting path 중 같은 단계의 Feature map을 가져와 합침
        # Up-Convolution 결과의 Feature map size 만큼 CenterCrop 하여 Concat 연산
        # 56x56x512 => 56x56x1024
        cat1 = torch.cat((transforms.CenterCrop((upconv1.shape[2], upconv1.shape[3]))(layer4), upconv1), dim=1)
        
        # 56x56x1024 => 52x52x512
        ex_layer1 = self.ex_conv1(cat1)

		# 52x52x512 => 104x104x256
        upconv2 = self.upconv2(ex_layer1)
        
        # Contracting path 중 같은 단계의 Feature map을 가져와 합침
        # Up-Convolution 결과의 Feature map size 만큼 CenterCrop 하여 Concat 연산
        # 104x104x256 => 104x104x512
        cat2 = torch.cat((transforms.CenterCrop((upconv2.shape[2], upconv2.shape[3]))(layer3), upconv2), dim=1)
        
        # 104x104x512 => 100x100x256
        ex_layer2 = self.ex_conv2(cat2)

		# 100x100x256 => 200x200x128
        upconv3 = self.upconv3(ex_layer2)
        
        # Contracting path 중 같은 단계의 Feature map을 가져와 합침
        # Up-Convolution 결과의 Feature map size 만큼 CenterCrop 하여 Concat 연산
        # 200x200x128 => 200x200x256
        cat3 = torch.cat((transforms.CenterCrop((upconv3.shape[2], upconv3.shape[3]))(layer2), upconv3), dim=1)
        
        # 200x200x256 => 196x196x128
        ex_layer3 = self.ex_conv3(cat3)

		# 196x196x128=> 392x392x64
        upconv4 = self.upconv4(ex_layer3)
        
        # Contracting path 중 같은 단계의 Feature map을 가져와 합침
        # Up-Convolution 결과의 Feature map size 만큼 CenterCrop 하여 Concat 연산
        # 392x392x64 => 392x392x128
        cat4 = torch.cat((transforms.CenterCrop((upconv4.shape[2], upconv4.shape[3]))(layer1), upconv4), dim=1)
        
        # 392x392x128 => 388x388x64
        out = self.ex_conv4(cat4)

		# 388x388x64 => 388x388x1
        out = self.fc(out)
        return out

# %%
from torchsummary import summary
Unet = UNet().to(device)
summary(Unet,input_size=(1,700,700))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 698, 698]             640
#        BatchNorm2d-2         [-1, 64, 698, 698]             128
#               ReLU-3         [-1, 64, 698, 698]               0
#             Conv2d-4         [-1, 64, 696, 696]          36,928
#        BatchNorm2d-5         [-1, 64, 696, 696]             128
#               ReLU-6         [-1, 64, 696, 696]               0
#          MaxPool2d-7         [-1, 64, 348, 348]               0
#             Conv2d-8        [-1, 128, 346, 346]          73,856
#        BatchNorm2d-9        [-1, 128, 346, 346]             256
#              ReLU-10        [-1, 128, 346, 346]               0
#            Conv2d-11        [-1, 128, 344, 344]         147,584
#       BatchNorm2d-12        [-1, 128, 344, 344]             256
#              ReLU-13        [-1, 128, 344, 344]               0
#         MaxPool2d-14        [-1, 128, 172, 172]               0
#            Conv2d-15        [-1, 256, 170, 170]         295,168
#       BatchNorm2d-16        [-1, 256, 170, 170]             512
#              ReLU-17        [-1, 256, 170, 170]               0
#            Conv2d-18        [-1, 256, 168, 168]         590,080
#       BatchNorm2d-19        [-1, 256, 168, 168]             512
#              ReLU-20        [-1, 256, 168, 168]               0
#         MaxPool2d-21          [-1, 256, 84, 84]               0
#            Conv2d-22          [-1, 512, 82, 82]       1,180,160
#       BatchNorm2d-23          [-1, 512, 82, 82]           1,024
#              ReLU-24          [-1, 512, 82, 82]               0
#            Conv2d-25          [-1, 512, 80, 80]       2,359,808
#       BatchNorm2d-26          [-1, 512, 80, 80]           1,024
#              ReLU-27          [-1, 512, 80, 80]               0
#           Dropout-28          [-1, 512, 80, 80]               0
#         MaxPool2d-29          [-1, 512, 40, 40]               0
#            Conv2d-30         [-1, 1024, 38, 38]       4,719,616
#       BatchNorm2d-31         [-1, 1024, 38, 38]           2,048
#              ReLU-32         [-1, 1024, 38, 38]               0
#            Conv2d-33         [-1, 1024, 36, 36]       9,438,208
#       BatchNorm2d-34         [-1, 1024, 36, 36]           2,048
#              ReLU-35         [-1, 1024, 36, 36]               0
#   ConvTranspose2d-36          [-1, 512, 72, 72]       2,097,664
#            Conv2d-37          [-1, 512, 70, 70]       4,719,104
#       BatchNorm2d-38          [-1, 512, 70, 70]           1,024
#              ReLU-39          [-1, 512, 70, 70]               0
#            Conv2d-40          [-1, 512, 68, 68]       2,359,808
#       BatchNorm2d-41          [-1, 512, 68, 68]           1,024
#              ReLU-42          [-1, 512, 68, 68]               0
#   ConvTranspose2d-43        [-1, 256, 136, 136]         524,544
#            Conv2d-44        [-1, 256, 134, 134]       1,179,904
#       BatchNorm2d-45        [-1, 256, 134, 134]             512
#              ReLU-46        [-1, 256, 134, 134]               0
#            Conv2d-47        [-1, 256, 132, 132]         590,080
#       BatchNorm2d-48        [-1, 256, 132, 132]             512
#              ReLU-49        [-1, 256, 132, 132]               0
#   ConvTranspose2d-50        [-1, 128, 264, 264]         131,200
#            Conv2d-51        [-1, 128, 262, 262]         295,040
#       BatchNorm2d-52        [-1, 128, 262, 262]             256
#              ReLU-53        [-1, 128, 262, 262]               0
#            Conv2d-54        [-1, 128, 260, 260]         147,584
#       BatchNorm2d-55        [-1, 128, 260, 260]             256
#              ReLU-56        [-1, 128, 260, 260]               0
#   ConvTranspose2d-57         [-1, 64, 520, 520]          32,832
#            Conv2d-58         [-1, 64, 518, 518]          73,792
#       BatchNorm2d-59         [-1, 64, 518, 518]             128
#              ReLU-60         [-1, 64, 518, 518]               0
#            Conv2d-61         [-1, 64, 516, 516]          36,928
#       BatchNorm2d-62         [-1, 64, 516, 516]             128
#              ReLU-63         [-1, 64, 516, 516]               0
#            Conv2d-64          [-1, 1, 516, 516]              65
# ================================================================
# Total params: 31,042,369
# Trainable params: 31,042,369
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 1.87
# Forward/backward pass size (MB): 4566.11
# Params size (MB): 118.42
# Estimated Total Size (MB): 4686.40
# ----------------------------------------------------------------

# %% [markdown]
# # 모델 만들기

# %% [markdown]
# # Dataset & transform

# %%
import numpy as np
import cv2
from PIL import Image

# %%
#im1 = Image.open(os.path.join('/content/drive/MyDrive/2d_images','/content/drive/MyDrive/2d_images/ID_0000_Z_0142.tif'))
im1 = cv2.imread(os.path.join('/content/drive/MyDrive/2d_images','/content/drive/MyDrive/2d_images/ID_0000_Z_0142.tif'))

#im1 = np.asarray(im1)
np.max(im1)
# Out:
# 255

# %%
im1 = cv2.cvtColor(im1,cv2.COLOR_BGR2RGB)
plt.imshow(im1)

# %%
input_data = os.listdir('/content/drive/MyDrive/2d_images')
label_data = os.listdir('/content/drive/MyDrive/2d_masks')

input_list = sorted([os.path.join('/content/drive/MyDrive/2d_images',f) for f in input_data])
label_list = sorted([os.path.join('/content/drive/MyDrive/2d_masks',f)for f in label_data if not f.endswith('(1).tif')])

input_list[0], label_list[0]
# Out:
# ('/content/drive/MyDrive/2d_images/ID_0000_Z_0142.tif',
#  '/content/drive/MyDrive/2d_masks/ID_0000_Z_0142.tif')

# %%
img = Image.open(input_list[1])
img = np.asarray(img)
img = img/1054.0
plt.imshow(img)

# %%
train_input_filepaths = input_list[:200]
val_input_filepaths = input_list[200:]

train_label_filepaths = label_list[:200]
val_label_filepaths = label_list[200:]
print(len(train_input_filepaths),len(val_input_filepaths))
# Out:
# 200 67

# %%
class UNetDataset(Dataset):
  def __init__(self, file_list,label_list,transform=None,phase='train'):
    self.file_list = file_list
    self.transform = transform
    self.label_list = label_list
    self.phase = phase

  def __len__(self):
    return len(self.file_list)

  #data load
  def __getitem__(self,index):
    img_path = self.file_list[index]

    img = Image.open(img_path)
    #img = Image.fromarray(img)
    img = img.resize((700,700))
    img = np.asarray(img) # /1054.0
    img = img.astype(np.float64)
    img_transformed = self.transform(img,self.phase)

    
    label = Image.open(self.label_list[index])
    label = label.resize((516,516))
    label = np.asarray(label)
    label = label.astype(np.float64)
    #label = label/1054.0
    label = Image.fromarray(label)
 
    img_label_transformed = self.transform(label,self.phase)

    return img_transformed, img_label_transformed

# %%
mean = (0.5,)
std = (0.5,)
batch_size = 4

# %%
class ImageTransform():
  def __init__(self,mean,std):
    self.data_transform = {
        'train': transforms.Compose([
            #transforms.Resize(resize),
            transforms.ToTensor(), #0~1로 바꿈
            transforms.Normalize(mean,std),
            transforms.ColorJitter(brightness=0.5),
            transforms.ColorJitter(contrast=0.5)
        ]),

        'val': transforms.Compose([
            #transforms.Resize(resize),
            transforms.ToTensor(),
            transforms.Normalize(mean,std),
            transforms.ColorJitter(brightness=0.5),
            transforms.ColorJitter(contrast=0.5)
        ])
    }

  def __call__(self, img, phase):
    return self.data_transform[phase](img)

# %%
train_dataset = UNetDataset(
    file_list = train_input_filepaths,
    label_list = train_label_filepaths,
    transform= ImageTransform(mean,std),
    
    phase='train'
)
val_dataset = UNetDataset(
    file_list = train_input_filepaths,
    label_list = train_label_filepaths,
    transform= ImageTransform(mean,std),
    phase='val'
)

# %%
print(val_dataset.__getitem__(0)[0].size(),val_dataset.__getitem__(0)[1].size())
# Out:
# torch.Size([1, 700, 700]) torch.Size([1, 516, 516])

# %%
train_dataloader = DataLoader(train_dataset, batch_size = batch_size, shuffle=True,num_workers=2)
val_dataloader = DataLoader(val_dataset, batch_size = batch_size, shuffle=True,num_workers=2)

dataloader_dict = {'train':train_dataloader,'val':val_dataloader}

batch_iterator = iter(train_dataloader)
inputs, labels = batch_iterator.next()

plt.figure(figsize=(10,8))
for i in range(0,4):
  plt.subplot(2,4,i+1)
  plt.imshow(inputs[i].permute(1, 2, 0).squeeze())
  plt.subplot(2,4,i+1+4)
  plt.imshow(labels[i].permute(1,2,0).squeeze())

# %%
lr = 1e-3
batch_size=4
num_epoch=3

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
Unet = UNet().to(device)

# %%
from torchsummary import summary

summary(Unet,input_size=(1,700,700))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 698, 698]             640
#        BatchNorm2d-2         [-1, 64, 698, 698]             128
#               ReLU-3         [-1, 64, 698, 698]               0
#             Conv2d-4         [-1, 64, 696, 696]          36,928
#        BatchNorm2d-5         [-1, 64, 696, 696]             128
#               ReLU-6         [-1, 64, 696, 696]               0
#          MaxPool2d-7         [-1, 64, 348, 348]               0
#             Conv2d-8        [-1, 128, 346, 346]          73,856
#        BatchNorm2d-9        [-1, 128, 346, 346]             256
#              ReLU-10        [-1, 128, 346, 346]               0
#            Conv2d-11        [-1, 128, 344, 344]         147,584
#       BatchNorm2d-12        [-1, 128, 344, 344]             256
#              ReLU-13        [-1, 128, 344, 344]               0
#         MaxPool2d-14        [-1, 128, 172, 172]               0
#            Conv2d-15        [-1, 256, 170, 170]         295,168
#       BatchNorm2d-16        [-1, 256, 170, 170]             512
#              ReLU-17        [-1, 256, 170, 170]               0
#            Conv2d-18        [-1, 256, 168, 168]         590,080
#       BatchNorm2d-19        [-1, 256, 168, 168]             512
#              ReLU-20        [-1, 256, 168, 168]               0
#         MaxPool2d-21          [-1, 256, 84, 84]               0
#            Conv2d-22          [-1, 512, 82, 82]       1,180,160
#       BatchNorm2d-23          [-1, 512, 82, 82]           1,024
#              ReLU-24          [-1, 512, 82, 82]               0
#            Conv2d-25          [-1, 512, 80, 80]       2,359,808
#       BatchNorm2d-26          [-1, 512, 80, 80]           1,024
#              ReLU-27          [-1, 512, 80, 80]               0
#           Dropout-28          [-1, 512, 80, 80]               0
#         MaxPool2d-29          [-1, 512, 40, 40]               0
#            Conv2d-30         [-1, 1024, 38, 38]       4,719,616
#       BatchNorm2d-31         [-1, 1024, 38, 38]           2,048
#              ReLU-32         [-1, 1024, 38, 38]               0
#            Conv2d-33         [-1, 1024, 36, 36]       9,438,208
#       BatchNorm2d-34         [-1, 1024, 36, 36]           2,048
#              ReLU-35         [-1, 1024, 36, 36]               0
#   ConvTranspose2d-36          [-1, 512, 72, 72]       2,097,664
#            Conv2d-37          [-1, 512, 70, 70]       4,719,104
#       BatchNorm2d-38          [-1, 512, 70, 70]           1,024
#              ReLU-39          [-1, 512, 70, 70]               0
#            Conv2d-40          [-1, 512, 68, 68]       2,359,808
#       BatchNorm2d-41          [-1, 512, 68, 68]           1,024
#              ReLU-42          [-1, 512, 68, 68]               0
#   ConvTranspose2d-43        [-1, 256, 136, 136]         524,544
#            Conv2d-44        [-1, 256, 134, 134]       1,179,904
#       BatchNorm2d-45        [-1, 256, 134, 134]             512
#              ReLU-46        [-1, 256, 134, 134]               0
#            Conv2d-47        [-1, 256, 132, 132]         590,080
#       BatchNorm2d-48        [-1, 256, 132, 132]             512
#              ReLU-49        [-1, 256, 132, 132]               0
#   ConvTranspose2d-50        [-1, 128, 264, 264]         131,200
#            Conv2d-51        [-1, 128, 262, 262]         295,040
#       BatchNorm2d-52        [-1, 128, 262, 262]             256
#              ReLU-53        [-1, 128, 262, 262]               0
#            Conv2d-54        [-1, 128, 260, 260]         147,584
#       BatchNorm2d-55        [-1, 128, 260, 260]             256
#              ReLU-56        [-1, 128, 260, 260]               0
#   ConvTranspose2d-57         [-1, 64, 520, 520]          32,832
#            Conv2d-58         [-1, 64, 518, 518]          73,792
#       BatchNorm2d-59         [-1, 64, 518, 518]             128
#              ReLU-60         [-1, 64, 518, 518]               0
#            Conv2d-61         [-1, 64, 516, 516]          36,928
#       BatchNorm2d-62         [-1, 64, 516, 516]             128
#              ReLU-63         [-1, 64, 516, 516]               0
#            Conv2d-64          [-1, 1, 516, 516]              65
# ================================================================
# Total params: 31,042,369
# Trainable params: 31,042,369
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 1.87
# Forward/backward pass size (MB): 4566.11
# Params size (MB): 118.42
# Estimated Total Size (MB): 4686.40
# ----------------------------------------------------------------

# %%
Unet.parameters()
# Out:
# <generator object Module.parameters at 0x7f755c27e8d0>

# %%
def count_parameters(model):
  return sum(p.numel() for p in model.parameters() if p.requires_grad) # numel : 파라미터 수 알려줌

par = count_parameters(Unet)
par
# Out:
# 31042369

# %%
criterion = nn.BCEWithLogitsLoss().to(device)
optimizer = torch.optim.Adam(Unet.parameters(),lr=lr)

# %%
import time

# %%
# !pip install --user tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.64.1)

# %%
from tqdm import tqdm_notebook as tqdm

# %%
data_dir = '/content/drive/MyDrive/Unet/data'
ckpt_dir = '/content/drive/MyDrive/Unet/checkpoint'
log_dir = '/content/drive/MyDrive/Unet/log'

# %%
from torch.utils.tensorboard import SummaryWriter
# 기타 variables 설정
num_train = len(train_dataset)
num_val = len(val_dataset)

num_train_for_epoch = np.ceil(num_train/batch_size) # np.ceil : 소수점 반올림
num_val_for_epoch = np.ceil(num_val/batch_size)

# 기타 function 설정
fn_tonumpy = lambda x : x.to('cpu').detach().numpy().transpose(0,2,3,1) # device 위에 올라간 텐서를 detach 한 뒤 numpy로 변환
fn_denorm = lambda x, mean, std : (x * std) + mean 
fn_classifier = lambda x :  1.0 * (x > 0.5)  # threshold 0.5 기준으로 indicator function으로 classifier 구현

# Tensorbord
writer_train = SummaryWriter(log_dir=os.path.join(log_dir,'train'))
writer_val = SummaryWriter(log_dir = os.path.join(log_dir,'val'))

# %%
def save(ckpt_dir,net,optim,epoch):
  if not os.path.exists(ckpt_dir):
    os.makedirs(ckpt_dir)
  torch.save({'net':Unet.state_dict(),'optim':optim.state_dict()},'%s/model_epoch%d.pth'%(ckpt_dir,epoch))

# 네트워크 불러오기
def load(ckpt_dir,net,optim):
    if not os.path.exists(ckpt_dir): # 저장된 네트워크가 없다면 인풋을 그대로 반환
        epoch = 0
        return net, optim, epoch
    
    ckpt_lst = os.listdir(ckpt_dir) # ckpt_dir 아래 있는 모든 파일 리스트를 받아온다
    ckpt_lst.sort(key = lambda f : int(''.join(filter(str.isdigit,f))))

    dict_model = torch.load('%s/%s' % (ckpt_dir,ckpt_lst[-1]))

    net.load_state_dict(dict_model['net'])
    optim.load_state_dict(dict_model['optim'])
    epoch = int(ckpt_lst[-1].split('epoch')[1].split('.pth')[0])

    return net,optim,epoch

# %%
# 네트워크 학습시키기
start_epoch = 0
#net, optim, start_epoch = load(ckpt_dir = ckpt_dir, net = Unet, optim = optimizer) # 저장된 네트워크 불러오기
net = Unet
optim = optimizer

for epoch in range(start_epoch+1,num_epoch +1):
    Unet.train()
    loss_arr = []

    for batch, data in enumerate(train_dataloader,1): # 1은 뭐니 > index start point
        # forward
        inputs = data[0].type(torch.FloatTensor).to(device)
        labels = data[1].to(device)   # 데이터 device로 올리기     

        output = Unet(inputs) 

        # backward
        optim.zero_grad()  # gradient 초기화
        loss = criterion(output, labels)  # output과 label 사이의 loss 계산
        loss.backward() # gradient backpropagation
        optim.step() # backpropa 된 gradient를 이용해서 각 layer의 parameters update

        # save loss
        loss_arr += [loss.item()]

        print('Train -> epoch {} / {} | Batch {} / {} | Loss {:.4f}'.format(epoch,num_epoch,batch,num_train_for_epoch,np.mean(loss_arr)))

        # tensorbord에 결과값들 저정하기
        labels = fn_tonumpy(labels)
        inputs = fn_tonumpy(fn_denorm(inputs,0.5,0.5))
        output = fn_tonumpy(fn_classifier(output))

        writer_train.add_image('labels', labels, num_train_for_epoch * (epoch - 1) + batch, dataformats='NHWC')
        writer_train.add_image('inputs', inputs, num_train_for_epoch * (epoch - 1) + batch, dataformats='NHWC')
        writer_train.add_image('output', output, num_train_for_epoch * (epoch - 1) + batch, dataformats='NHWC')

    writer_train.add_scalar('loss', np.mean(loss_arr), epoch)

    
    # validation
    with torch.no_grad(): # validation 이기 때문에 backpropa 진행 x, 학습된 네트워크가 정답과 얼마나 가까운지 loss만 계산
        Unet.eval() # 네트워크를 evaluation 용으로 선언
        loss_arr = []

        for batch, data in enumerate(val_dataloader,1):
            # forward
            inputs = data[0].type(torch.FloatTensor).to(device)
            labels = data[1].to(device)
            output = Unet(inputs)

            # loss 
            loss = criterion(output,labels)
            loss_arr += [loss.item()]
            print('Val -> epoch {} / {} | Batch {} / {} | Loss {:.4f}'.format(epoch,num_epoch,batch,num_val_for_epoch,np.mean(loss_arr)))


            # Tensorboard 저장하기
            labels = fn_tonumpy(labels)
            inputs = fn_tonumpy(fn_denorm(inputs, mean=0.5, std=0.5))
            output = fn_tonumpy(fn_classifier(output))

            writer_val.add_image('labels', labels, num_val_for_epoch * (epoch - 1) + batch, dataformats='NHWC')
            writer_val.add_image('input', inputs, num_val_for_epoch * (epoch - 1) + batch, dataformats='NHWC')
            writer_val.add_image('output', output, num_val_for_epoch * (epoch - 1) + batch, dataformats='NHWC')

        writer_val.add_scalar('loss', np.mean(loss_arr), epoch)

        # epoch이 끝날때 마다 네트워크 저장
        save(ckpt_dir=ckpt_dir, net = Unet, optim = optim, epoch = epoch)

writer_train.close()
writer_val.close()
# Out:
# Train -> epoch 1 / 3 | Batch 1 / 50.0 | Loss 0.7265
# Train -> epoch 1 / 3 | Batch 2 / 50.0 | Loss 0.7258
# Train -> epoch 1 / 3 | Batch 3 / 50.0 | Loss 0.7062
# Train -> epoch 1 / 3 | Batch 4 / 50.0 | Loss 0.6944
# Train -> epoch 1 / 3 | Batch 5 / 50.0 | Loss 0.6836
# Train -> epoch 1 / 3 | Batch 6 / 50.0 | Loss 0.6738
# Train -> epoch 1 / 3 | Batch 7 / 50.0 | Loss 0.6632
# Train -> epoch 1 / 3 | Batch 8 / 50.0 | Loss 0.6523
# Train -> epoch 1 / 3 | Batch 9 / 50.0 | Loss 0.6452
# Train -> epoch 1 / 3 | Batch 10 / 50.0 | Loss 0.6395
# Train -> epoch 1 / 3 | Batch 11 / 50.0 | Loss 0.6337
# Train -> epoch 1 / 3 | Batch 12 / 50.0 | Loss 0.6272
# Train -> epoch 1 / 3 | Batch 13 / 50.0 | Loss 0.6221
# Train -> epoch 1 / 3 | Batch 14 / 50.0 | Loss 0.6149
# Train -> epoch 1 / 3 | Batch 15 / 50.0 | Loss 0.6103
# Train -> epoch 1 / 3 | Batch 16 / 50.0 | Loss 0.6073
# Train -> epoch 1 / 3 | Batch 17 / 50.0 | Loss 0.5995
# Train -> epoch 1 / 3 | Batch 18 / 50.0 | Loss 0.5944
# Train -> epoch 1 / 3 | Batch 19 / 50.0 | Loss 0.5903
# Train -> epoch 1 / 3 | Batch 20 / 50.0 | Loss 0.5847
# Train -> epoch 1 / 3 | Batch 21 / 50.0 | Loss 0.5777
# Train -> epoch 1 / 3 | Batch 22 / 50.0 | Loss 0.5719
# Train -> epoch 1 / 3 | Batch 23 / 50.0 | Loss 0.5665
# Train -> epoch 1 / 3 | Batch 24 / 50.0 | Loss 0.5620
# Train -> epoch 1 / 3 | Batch 25 / 50.0 | Loss 0.5556
# Train -> epoch 1 / 3 | Batch 26 / 50.0 | Loss 0.5524
# Train -> epoch 1 / 3 | Batch 27 / 50.0 | Loss 0.5479
# Train -> epoch 1 / 3 | Batch 28 / 50.0 | Loss 0.5444
# Train -> epoch 1 / 3 | Batch 29 / 50.0 | Loss 0.5427
# Train -> epoch 1 / 3 | Batch 30 / 50.0 | Loss 0.5402
# Train -> epoch 1 / 3 | Batch 31 / 50.0 | Loss 0.5382
# Train -> epoch 1 / 3 | Batch 32 / 50.0 | Loss 0.5346
# Train -> epoch 1 / 3 | Batch 33 / 50.0 | Loss 0.5324
# Train -> epoch 1 / 3 | Batch 34 / 50.0 | Loss 0.5288
# Train -> epoch 1 / 3 | Batch 35 / 50.0 | Loss 0.5252
# Train -> epoch 1 / 3 | Batch 36 / 50.0 | Loss 0.5224
# Train -> epoch 1 / 3 | Batch 37 / 50.0 | Loss 0.5181
# Train -> epoch 1 / 3 | Batch 38 / 50.0 | Loss 0.5151
# Train -> epoch 1 / 3 | Batch 39 / 50.0 | Loss 0.5113
# Train -> epoch 1 / 3 | Batch 40 / 50.0 | Loss 0.5083
# Train -> epoch 1 / 3 | Batch 41 / 50.0 | Loss 0.5051
# Train -> epoch 1 / 3 | Batch 42 / 50.0 | Loss 0.5035
# Train -> epoch 1 / 3 | Batch 43 / 50.0 | Loss 0.5030
# Train -> epoch 1 / 3 | Batch 44 / 50.0 | Loss 0.4988
# Train -> epoch 1 / 3 | Batch 45 / 50.0 | Loss 0.4968
# Train -> epoch 1 / 3 | Batch 46 / 50.0 | Loss 0.4946
# Train -> epoch 1 / 3 | Batch 47 / 50.0 | Loss 0.4928
# Train -> epoch 1 / 3 | Batch 48 / 50.0 | Loss 0.4902
# Train -> epoch 1 / 3 | Batch 49 / 50.0 | Loss 0.4880
# Train -> epoch 1 / 3 | Batch 50 / 50.0 | Loss 0.4874
# Val -> epoch 1 / 3 | Batch 1 / 50.0 | Loss 0.9406
# Val -> epoch 1 / 3 | Batch 2 / 50.0 | Loss 0.8672
# Val -> epoch 1 / 3 | Batch 3 / 50.0 | Loss 0.9028
# Val -> epoch 1 / 3 | Batch 4 / 50.0 | Loss 0.8470
# Val -> epoch 1 / 3 | Batch 5 / 50.0 | Loss 0.7865
# Val -> epoch 1 / 3 | Batch 6 / 50.0 | Loss 0.8059
# Val -> epoch 1 / 3 | Batch 7 / 50.0 | Loss 0.7990
# Val -> epoch 1 / 3 | Batch 8 / 50.0 | Loss 0.8013
# Val -> epoch 1 / 3 | Batch 9 / 50.0 | Loss 0.8060
# Val -> epoch 1 / 3 | Batch 10 / 50.0 | Loss 0.8031
# Val -> epoch 1 / 3 | Batch 11 / 50.0 | Loss 0.7906
# Val -> epoch 1 / 3 | Batch 12 / 50.0 | Loss 0.7950
# Val -> epoch 1 / 3 | Batch 13 / 50.0 | Loss 0.7896
# Val -> epoch 1 / 3 | Batch 14 / 50.0 | Loss 0.7780
# Val -> epoch 1 / 3 | Batch 15 / 50.0 | Loss 0.7827
# Val -> epoch 1 / 3 | Batch 16 / 50.0 | Loss 0.7804
# Val -> epoch 1 / 3 | Batch 17 / 50.0 | Loss 0.7757
# Val -> epoch 1 / 3 | Batch 18 / 50.0 | Loss 0.7677
# Val -> epoch 1 / 3 | Batch 19 / 50.0 | Loss 0.7655
# Val -> epoch 1 / 3 | Batch 20 / 50.0 | Loss 0.7628
# Val -> epoch 1 / 3 | Batch 21 / 50.0 | Loss 0.7614
# Val -> epoch 1 / 3 | Batch 22 / 50.0 | Loss 0.7645
# Val -> epoch 1 / 3 | Batch 23 / 50.0 | Loss 0.7581
# Val -> epoch 1 / 3 | Batch 24 / 50.0 | Loss 0.7566
# Val -> epoch 1 / 3 | Batch 25 / 50.0 | Loss 0.7562
# Val -> epoch 1 / 3 | Batch 26 / 50.0 | Loss 0.7582
# Val -> epoch 1 / 3 | Batch 27 / 50.0 | Loss 0.7531
# Val -> epoch 1 / 3 | Batch 28 / 50.0 | Loss 0.7517
# Val -> epoch 1 / 3 | Batch 29 / 50.0 | Loss 0.7543
# Val -> epoch 1 / 3 | Batch 30 / 50.0 | Loss 0.7556
# Val -> epoch 1 / 3 | Batch 31 / 50.0 | Loss 0.7572
# Val -> epoch 1 / 3 | Batch 32 / 50.0 | Loss 0.7518
# Val -> epoch 1 / 3 | Batch 33 / 50.0 | Loss 0.7543
# Val -> epoch 1 / 3 | Batch 34 / 50.0 | Loss 0.7494
# Val -> epoch 1 / 3 | Batch 35 / 50.0 | Loss 0.7494
# Val -> epoch 1 / 3 | Batch 36 / 50.0 | Loss 0.7512
# Val -> epoch 1 / 3 | Batch 37 / 50.0 | Loss 0.7462
# Val -> epoch 1 / 3 | Batch 38 / 50.0 | Loss 0.7479
# Val -> epoch 1 / 3 | Batch 39 / 50.0 | Loss 0.7476
# Val -> epoch 1 / 3 | Batch 40 / 50.0 | Loss 0.7503
# Val -> epoch 1 / 3 | Batch 41 / 50.0 | Loss 0.7476
# Val -> epoch 1 / 3 | Batch 42 / 50.0 | Loss 0.7481
# Val -> epoch 1 / 3 | Batch 43 / 50.0 | Loss 0.7464
# Val -> epoch 1 / 3 | Batch 44 / 50.0 | Loss 0.7467
# Val -> epoch 1 / 3 | Batch 45 / 50.0 | Loss 0.7418
# Val -> epoch 1 / 3 | Batch 46 / 50.0 | Loss 0.7383
# Val -> epoch 1 / 3 | Batch 47 / 50.0 | Loss 0.7375
# Val -> epoch 1 / 3 | Batch 48 / 50.0 | Loss 0.7350
# Val -> epoch 1 / 3 | Batch 49 / 50.0 | Loss 0.7351
# Val -> epoch 1 / 3 | Batch 50 / 50.0 | Loss 0.7336
# Train -> epoch 2 / 3 | Batch 1 / 50.0 | Loss 0.4102
# Train -> epoch 2 / 3 | Batch 2 / 50.0 | Loss 0.3730
# Train -> epoch 2 / 3 | Batch 3 / 50.0 | Loss 0.3666
# Train -> epoch 2 / 3 | Batch 4 / 50.0 | Loss 0.3785
# Train -> epoch 2 / 3 | Batch 5 / 50.0 | Loss 0.3775
# Train -> epoch 2 / 3 | Batch 6 / 50.0 | Loss 0.3734
# Train -> epoch 2 / 3 | Batch 7 / 50.0 | Loss 0.3784
# Train -> epoch 2 / 3 | Batch 8 / 50.0 | Loss 0.3809
# Train -> epoch 2 / 3 | Batch 9 / 50.0 | Loss 0.3828
# Train -> epoch 2 / 3 | Batch 10 / 50.0 | Loss 0.3789
# Train -> epoch 2 / 3 | Batch 11 / 50.0 | Loss 0.3737
# Train -> epoch 2 / 3 | Batch 12 / 50.0 | Loss 0.3779
# Train -> epoch 2 / 3 | Batch 13 / 50.0 | Loss 0.3814
# Train -> epoch 2 / 3 | Batch 14 / 50.0 | Loss 0.3747
# Train -> epoch 2 / 3 | Batch 15 / 50.0 | Loss 0.3766
# Train -> epoch 2 / 3 | Batch 16 / 50.0 | Loss 0.3688
# Train -> epoch 2 / 3 | Batch 17 / 50.0 | Loss 0.3655
# Train -> epoch 2 / 3 | Batch 18 / 50.0 | Loss 0.3636
# Train -> epoch 2 / 3 | Batch 19 / 50.0 | Loss 0.3638
# Train -> epoch 2 / 3 | Batch 20 / 50.0 | Loss 0.3629
# Train -> epoch 2 / 3 | Batch 21 / 50.0 | Loss 0.3620
# Train -> epoch 2 / 3 | Batch 22 / 50.0 | Loss 0.3598
# Train -> epoch 2 / 3 | Batch 23 / 50.0 | Loss 0.3578
# Train -> epoch 2 / 3 | Batch 24 / 50.0 | Loss 0.3573
# Train -> epoch 2 / 3 | Batch 25 / 50.0 | Loss 0.3601
# Train -> epoch 2 / 3 | Batch 26 / 50.0 | Loss 0.3568
# Train -> epoch 2 / 3 | Batch 27 / 50.0 | Loss 0.3540
# Train -> epoch 2 / 3 | Batch 28 / 50.0 | Loss 0.3548
# Train -> epoch 2 / 3 | Batch 29 / 50.0 | Loss 0.3533
# Train -> epoch 2 / 3 | Batch 30 / 50.0 | Loss 0.3543
# Train -> epoch 2 / 3 | Batch 31 / 50.0 | Loss 0.3526
# Train -> epoch 2 / 3 | Batch 32 / 50.0 | Loss 0.3501
# Train -> epoch 2 / 3 | Batch 33 / 50.0 | Loss 0.3498
# Train -> epoch 2 / 3 | Batch 34 / 50.0 | Loss 0.3497
# Train -> epoch 2 / 3 | Batch 35 / 50.0 | Loss 0.3494
# Train -> epoch 2 / 3 | Batch 36 / 50.0 | Loss 0.3512
# Train -> epoch 2 / 3 | Batch 37 / 50.0 | Loss 0.3486
# Train -> epoch 2 / 3 | Batch 38 / 50.0 | Loss 0.3480
# Train -> epoch 2 / 3 | Batch 39 / 50.0 | Loss 0.3462
# Train -> epoch 2 / 3 | Batch 40 / 50.0 | Loss 0.3455
# Train -> epoch 2 / 3 | Batch 41 / 50.0 | Loss 0.3454
# Train -> epoch 2 / 3 | Batch 42 / 50.0 | Loss 0.3422
# Train -> epoch 2 / 3 | Batch 43 / 50.0 | Loss 0.3423
# Train -> epoch 2 / 3 | Batch 44 / 50.0 | Loss 0.3401
# Train -> epoch 2 / 3 | Batch 45 / 50.0 | Loss 0.3380
# Train -> epoch 2 / 3 | Batch 46 / 50.0 | Loss 0.3373
# Train -> epoch 2 / 3 | Batch 47 / 50.0 | Loss 0.3374
# Train -> epoch 2 / 3 | Batch 48 / 50.0 | Loss 0.3347
# Train -> epoch 2 / 3 | Batch 49 / 50.0 | Loss 0.3355
# Train -> epoch 2 / 3 | Batch 50 / 50.0 | Loss 0.3360
# Val -> epoch 2 / 3 | Batch 1 / 50.0 | Loss 0.4100
# Val -> epoch 2 / 3 | Batch 2 / 50.0 | Loss 0.3711
# Val -> epoch 2 / 3 | Batch 3 / 50.0 | Loss 0.3647
# Val -> epoch 2 / 3 | Batch 4 / 50.0 | Loss 0.3857
# Val -> epoch 2 / 3 | Batch 5 / 50.0 | Loss 0.3800
# Val -> epoch 2 / 3 | Batch 6 / 50.0 | Loss 0.3773
# Val -> epoch 2 / 3 | Batch 7 / 50.0 | Loss 0.3838
# Val -> epoch 2 / 3 | Batch 8 / 50.0 | Loss 0.3814
# Val -> epoch 2 / 3 | Batch 9 / 50.0 | Loss 0.3936
# Val -> epoch 2 / 3 | Batch 10 / 50.0 | Loss 0.4066
# Val -> epoch 2 / 3 | Batch 11 / 50.0 | Loss 0.4122
# Val -> epoch 2 / 3 | Batch 12 / 50.0 | Loss 0.4193
# Val -> epoch 2 / 3 | Batch 13 / 50.0 | Loss 0.4187
# Val -> epoch 2 / 3 | Batch 14 / 50.0 | Loss 0.4179
# Val -> epoch 2 / 3 | Batch 15 / 50.0 | Loss 0.4174
# Val -> epoch 2 / 3 | Batch 16 / 50.0 | Loss 0.4165
# Val -> epoch 2 / 3 | Batch 17 / 50.0 | Loss 0.4195
# Val -> epoch 2 / 3 | Batch 18 / 50.0 | Loss 0.4239
# Val -> epoch 2 / 3 | Batch 19 / 50.0 | Loss 0.4255
# Val -> epoch 2 / 3 | Batch 20 / 50.0 | Loss 0.4215
# Val -> epoch 2 / 3 | Batch 21 / 50.0 | Loss 0.4204
# Val -> epoch 2 / 3 | Batch 22 / 50.0 | Loss 0.4188
# Val -> epoch 2 / 3 | Batch 23 / 50.0 | Loss 0.4135
# Val -> epoch 2 / 3 | Batch 24 / 50.0 | Loss 0.4134
# Val -> epoch 2 / 3 | Batch 25 / 50.0 | Loss 0.4139
# Val -> epoch 2 / 3 | Batch 26 / 50.0 | Loss 0.4170
# Val -> epoch 2 / 3 | Batch 27 / 50.0 | Loss 0.4160
# Val -> epoch 2 / 3 | Batch 28 / 50.0 | Loss 0.4126
# Val -> epoch 2 / 3 | Batch 29 / 50.0 | Loss 0.4138
# Val -> epoch 2 / 3 | Batch 30 / 50.0 | Loss 0.4192
# Val -> epoch 2 / 3 | Batch 31 / 50.0 | Loss 0.4221
# Val -> epoch 2 / 3 | Batch 32 / 50.0 | Loss 0.4194
# Val -> epoch 2 / 3 | Batch 33 / 50.0 | Loss 0.4188
# Val -> epoch 2 / 3 | Batch 34 / 50.0 | Loss 0.4213
# Val -> epoch 2 / 3 | Batch 35 / 50.0 | Loss 0.4209
# Val -> epoch 2 / 3 | Batch 36 / 50.0 | Loss 0.4192
# Val -> epoch 2 / 3 | Batch 37 / 50.0 | Loss 0.4177
# Val -> epoch 2 / 3 | Batch 38 / 50.0 | Loss 0.4182
# Val -> epoch 2 / 3 | Batch 39 / 50.0 | Loss 0.4170
# Val -> epoch 2 / 3 | Batch 40 / 50.0 | Loss 0.4162
# Val -> epoch 2 / 3 | Batch 41 / 50.0 | Loss 0.4145
# Val -> epoch 2 / 3 | Batch 42 / 50.0 | Loss 0.4157
# Val -> epoch 2 / 3 | Batch 43 / 50.0 | Loss 0.4147
# Val -> epoch 2 / 3 | Batch 44 / 50.0 | Loss 0.4160
# Val -> epoch 2 / 3 | Batch 45 / 50.0 | Loss 0.4179
# Val -> epoch 2 / 3 | Batch 46 / 50.0 | Loss 0.4164
# Val -> epoch 2 / 3 | Batch 47 / 50.0 | Loss 0.4199
# Val -> epoch 2 / 3 | Batch 48 / 50.0 | Loss 0.4184
# Val -> epoch 2 / 3 | Batch 49 / 50.0 | Loss 0.4174
# Val -> epoch 2 / 3 | Batch 50 / 50.0 | Loss 0.4161
# Train -> epoch 3 / 3 | Batch 1 / 50.0 | Loss 0.3136
# Train -> epoch 3 / 3 | Batch 2 / 50.0 | Loss 0.3725
# Train -> epoch 3 / 3 | Batch 3 / 50.0 | Loss 0.3626
# Train -> epoch 3 / 3 | Batch 4 / 50.0 | Loss 0.3502
# Train -> epoch 3 / 3 | Batch 5 / 50.0 | Loss 0.3389
# Train -> epoch 3 / 3 | Batch 6 / 50.0 | Loss 0.3433
# Train -> epoch 3 / 3 | Batch 7 / 50.0 | Loss 0.3390
# Train -> epoch 3 / 3 | Batch 8 / 50.0 | Loss 0.3371
# Train -> epoch 3 / 3 | Batch 9 / 50.0 | Loss 0.3295
# Train -> epoch 3 / 3 | Batch 10 / 50.0 | Loss 0.3276
# Train -> epoch 3 / 3 | Batch 11 / 50.0 | Loss 0.3306
# Train -> epoch 3 / 3 | Batch 12 / 50.0 | Loss 0.3233
# Train -> epoch 3 / 3 | Batch 13 / 50.0 | Loss 0.3154
# Train -> epoch 3 / 3 | Batch 14 / 50.0 | Loss 0.3179
# Train -> epoch 3 / 3 | Batch 15 / 50.0 | Loss 0.3269
# Train -> epoch 3 / 3 | Batch 16 / 50.0 | Loss 0.3284
# Train -> epoch 3 / 3 | Batch 17 / 50.0 | Loss 0.3336
# Train -> epoch 3 / 3 | Batch 18 / 50.0 | Loss 0.3294
# Train -> epoch 3 / 3 | Batch 19 / 50.0 | Loss 0.3310
# Train -> epoch 3 / 3 | Batch 20 / 50.0 | Loss 0.3275
# Train -> epoch 3 / 3 | Batch 21 / 50.0 | Loss 0.3281
# Train -> epoch 3 / 3 | Batch 22 / 50.0 | Loss 0.3286
# Train -> epoch 3 / 3 | Batch 23 / 50.0 | Loss 0.3402
# Train -> epoch 3 / 3 | Batch 24 / 50.0 | Loss 0.3393
# Train -> epoch 3 / 3 | Batch 25 / 50.0 | Loss 0.3377
# Train -> epoch 3 / 3 | Batch 26 / 50.0 | Loss 0.3365
# Train -> epoch 3 / 3 | Batch 27 / 50.0 | Loss 0.3345
# Train -> epoch 3 / 3 | Batch 28 / 50.0 | Loss 0.3324
# Train -> epoch 3 / 3 | Batch 29 / 50.0 | Loss 0.3324
# Train -> epoch 3 / 3 | Batch 30 / 50.0 | Loss 0.3299
# Train -> epoch 3 / 3 | Batch 31 / 50.0 | Loss 0.3286
# Train -> epoch 3 / 3 | Batch 32 / 50.0 | Loss 0.3277
# Train -> epoch 3 / 3 | Batch 33 / 50.0 | Loss 0.3258
# Train -> epoch 3 / 3 | Batch 34 / 50.0 | Loss 0.3228
# Train -> epoch 3 / 3 | Batch 35 / 50.0 | Loss 0.3219
# Train -> epoch 3 / 3 | Batch 36 / 50.0 | Loss 0.3234
# Train -> epoch 3 / 3 | Batch 37 / 50.0 | Loss 0.3228
# Train -> epoch 3 / 3 | Batch 38 / 50.0 | Loss 0.3198
# Train -> epoch 3 / 3 | Batch 39 / 50.0 | Loss 0.3185
# Train -> epoch 3 / 3 | Batch 40 / 50.0 | Loss 0.3173
# Train -> epoch 3 / 3 | Batch 41 / 50.0 | Loss 0.3175
# Train -> epoch 3 / 3 | Batch 42 / 50.0 | Loss 0.3178
# Train -> epoch 3 / 3 | Batch 43 / 50.0 | Loss 0.3175
# Train -> epoch 3 / 3 | Batch 44 / 50.0 | Loss 0.3180
# Train -> epoch 3 / 3 | Batch 45 / 50.0 | Loss 0.3186
# Train -> epoch 3 / 3 | Batch 46 / 50.0 | Loss 0.3177
# Train -> epoch 3 / 3 | Batch 47 / 50.0 | Loss 0.3185
# Train -> epoch 3 / 3 | Batch 48 / 50.0 | Loss 0.3182
# Train -> epoch 3 / 3 | Batch 49 / 50.0 | Loss 0.3207
# Train -> epoch 3 / 3 | Batch 50 / 50.0 | Loss 0.3219
# Val -> epoch 3 / 3 | Batch 1 / 50.0 | Loss 0.5634
# Val -> epoch 3 / 3 | Batch 2 / 50.0 | Loss 0.4799
# Val -> epoch 3 / 3 | Batch 3 / 50.0 | Loss 0.4587
# Val -> epoch 3 / 3 | Batch 4 / 50.0 | Loss 0.4706
# Val -> epoch 3 / 3 | Batch 5 / 50.0 | Loss 0.4572
# Val -> epoch 3 / 3 | Batch 6 / 50.0 | Loss 0.4639
# Val -> epoch 3 / 3 | Batch 7 / 50.0 | Loss 0.4725
# Val -> epoch 3 / 3 | Batch 8 / 50.0 | Loss 0.4953
# Val -> epoch 3 / 3 | Batch 9 / 50.0 | Loss 0.4913
# Val -> epoch 3 / 3 | Batch 10 / 50.0 | Loss 0.5005
# Val -> epoch 3 / 3 | Batch 11 / 50.0 | Loss 0.4971
# Val -> epoch 3 / 3 | Batch 12 / 50.0 | Loss 0.5064
# Val -> epoch 3 / 3 | Batch 13 / 50.0 | Loss 0.5172
# Val -> epoch 3 / 3 | Batch 14 / 50.0 | Loss 0.5050
# Val -> epoch 3 / 3 | Batch 15 / 50.0 | Loss 0.5045
# Val -> epoch 3 / 3 | Batch 16 / 50.0 | Loss 0.5124
# Val -> epoch 3 / 3 | Batch 17 / 50.0 | Loss 0.5062
# Val -> epoch 3 / 3 | Batch 18 / 50.0 | Loss 0.5013
# Val -> epoch 3 / 3 | Batch 19 / 50.0 | Loss 0.5013
# Val -> epoch 3 / 3 | Batch 20 / 50.0 | Loss 0.5013
# Val -> epoch 3 / 3 | Batch 21 / 50.0 | Loss 0.5050
# Val -> epoch 3 / 3 | Batch 22 / 50.0 | Loss 0.5090
# Val -> epoch 3 / 3 | Batch 23 / 50.0 | Loss 0.5138
# Val -> epoch 3 / 3 | Batch 24 / 50.0 | Loss 0.5113
# Val -> epoch 3 / 3 | Batch 25 / 50.0 | Loss 0.5100
# Val -> epoch 3 / 3 | Batch 26 / 50.0 | Loss 0.5058
# Val -> epoch 3 / 3 | Batch 27 / 50.0 | Loss 0.5015
# Val -> epoch 3 / 3 | Batch 28 / 50.0 | Loss 0.5012
# Val -> epoch 3 / 3 | Batch 29 / 50.0 | Loss 0.4984
# Val -> epoch 3 / 3 | Batch 30 / 50.0 | Loss 0.5007
# Val -> epoch 3 / 3 | Batch 31 / 50.0 | Loss 0.5006
# Val -> epoch 3 / 3 | Batch 32 / 50.0 | Loss 0.4995
# Val -> epoch 3 / 3 | Batch 33 / 50.0 | Loss 0.4985
# Val -> epoch 3 / 3 | Batch 34 / 50.0 | Loss 0.4954
# Val -> epoch 3 / 3 | Batch 35 / 50.0 | Loss 0.4958
# Val -> epoch 3 / 3 | Batch 36 / 50.0 | Loss 0.4927
# Val -> epoch 3 / 3 | Batch 37 / 50.0 | Loss 0.4906
# Val -> epoch 3 / 3 | Batch 38 / 50.0 | Loss 0.4916
# Val -> epoch 3 / 3 | Batch 39 / 50.0 | Loss 0.4895
# Val -> epoch 3 / 3 | Batch 40 / 50.0 | Loss 0.4866
# Val -> epoch 3 / 3 | Batch 41 / 50.0 | Loss 0.4900
# Val -> epoch 3 / 3 | Batch 42 / 50.0 | Loss 0.4892
# Val -> epoch 3 / 3 | Batch 43 / 50.0 | Loss 0.4923
# Val -> epoch 3 / 3 | Batch 44 / 50.0 | Loss 0.4912
# Val -> epoch 3 / 3 | Batch 45 / 50.0 | Loss 0.4915
# Val -> epoch 3 / 3 | Batch 46 / 50.0 | Loss 0.4893
# Val -> epoch 3 / 3 | Batch 47 / 50.0 | Loss 0.4899
# Val -> epoch 3 / 3 | Batch 48 / 50.0 | Loss 0.4907
# Val -> epoch 3 / 3 | Batch 49 / 50.0 | Loss 0.4937
# Val -> epoch 3 / 3 | Batch 50 / 50.0 | Loss 0.4955

# %%
torch.save(Unet.state_dict(),"/content/drive/MyDrive/Unet/unet.pth")
